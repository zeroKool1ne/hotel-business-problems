# %%
import os
os.getcwd()
# Out:
# '/Users/dv/Documents/myProjects/hotel-business-problems/notebooks'

# %%
import sys
import os

# Add project root to PYTHONPATH
project_root = os.path.abspath("..")
if project_root not in sys.path:
    sys.path.append(project_root)

# %% [markdown]
# # Cleaning Notebook

# %% [markdown]
# ## 1. Import Functions and load dataset

# %%
import pandas as pd
from src.cleaning import clean_dataset

df = pd.read_csv("https://raw.githubusercontent.com/zeroKool1ne/hotel-business-problems/refs/heads/main/data/raw/hotel_booking.csv")

# %% [markdown]
# ## 2. Apply functions

# %%
df_clean, dropped_cols = clean_dataset(df)

# %% [markdown]
# ## 3. Save dataset to Github repo

# %%
df_clean.to_csv("https://raw.githubusercontent.com/zeroKool1ne/hotel-business-problems/refs/heads/main//data/processed/hotel_dataset_cleaned", index=False)

# %% [markdown]
# ## 4. Check if data is clean

# %%
df_clean.head()
df_clean.info()
df_clean.isna().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117044 entries, 0 to 117043
# Data columns (total 36 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           117044 non-null  object
#  1   is_canceled                     117044 non-null  int64
#  2   lead_time                       117044 non-null  int64
#  3   arrival_date_year               117044 non-null  int64
#  4   arrival_date_month              117044 non-null  object
#  5   arrival_date_week_number        117044 non-null  int64
#  6   arrival_date_day_of_month       117044 non-null  int64
#  7   stays_in_weekend_nights         117044 non-null  int64
#  8   stays_in_week_nights            117044 non-null  int64
#  9   adults                          117044 non-null  int64
#  10  children                        117044 non-null  int64
#  11  babies                          117044 non-null  int64
# ...
